# %% [markdown]
# Script to simulate hydrodynamics over a river section based on different discharges upstream.
#
# The physical calculations are performed by the analytical model based on the Manning formula, for which stationar and uniform flow is assumed:
#
#     Q=K S^0,5 A R^(2/3)
#
# To do that first the geometric parameters (hydraulic radius, perimeter and surface area) are computed by the function conv_function_basic() based on the input of a criss section('data_bat_csv).
#
# Since we are not always dealing with normal flow a backwatercurve is performed by the Bresse fit
#     d = de + (d0-de)2^(L/105) with L05 - 0.24 de /S*d(d0/de)^0,75
#
# By Bart Strijker, adapted by Koen Hiemstra. Koen Hiemstra applied a method for Transverse slope and Bedforms.
#
#
# Version Frederik:
# This is a concept model for PhD-research of the Rhine branches. In this case the river stretch Waal.

# %%
#In this cell all the needed packages in this script are imported:

import math
from numpy import *
import matplotlib.pyplot as plt
import csv
from scipy.optimize import fsolve,newton
import networkx as nx

# %%
#Physical parameters
g=9.81

# %% [markdown]
# ## Define the parameters of the river system

# %%
#Bathymetry river system: This is a file based on the data of a SOBEK-simulation in 2013 (provided by Max Schropp to Koen Hiemstra).
with open ('River_branches_data.csv') as f:   #Reading csv file with bathymetry data of the river branches
    reader = csv.reader(f, delimiter=';')
    base_list = list(reader)
    mylist=base_list[1:681]

# Define lists of parameters
    
    point=[]
    name=[]
    x=[]
    y=[]
    kms=[]
    waterlevels=[]
    waterlevels700=[]
    width_summerbed=[]
    level_summerbed=[]
    level_winterbed=[]
    chezy=[] 

    for row in mylist:
        point.append(row [0])
        name.append(row [1])
        x.append(row[2])
        y.append(row[3])
        kms.append(row[5])
        waterlevels.append(row [9])
        waterlevels700.append(row[8])
        width_summerbed.append(row[11])
        level_summerbed.append(row[21])
        level_winterbed.append(row[24])
        chezy.append(row[27])        

# Change items of list from strings to floating numbers or integer 
location = [int(i) for i in point]
X = [float(i) for i in x] #positie moet nog door 1000 worden gedeeld om oorspronkelijke coordinaten terug te krijgen
Xco = [X[n]/1000 for n in range (0,len(X))]
Y = [float(i) for i in y] #positie moet nog door 1000 worden gedeeld om oorspronkelijke coordinaten terug te krijgen
Yco = [Y[n]/1000 for n in range (0,len(Y))]
KM = [int(i) for i in kms]
Waterlevel = [int(i) for i in waterlevels] #waterlevels in centimeters
Waterlevels700 = [int(i) for i in waterlevels700]#waterlevels in centimeters
Width_summerbed = [int(i) for i in width_summerbed] # width in meter
Level_summerbed = [int(i) for i in level_summerbed] # NAP + centimeters
Level_winterbed = [int(i) for i in level_winterbed] # NAP + centimeters
Chezy = [int(i) for i in chezy]

# %%
# Define the different riverstretches of the system
# Bovenrijn = cell 0:8
# Waal = cell 9:195
# Pannerdensch kanaal = cell 196:220
# Nederrijn = cell 221:319
# Lek = cell 320:440
# Yssel = cell 441:669
# Keteldiep = cell 670:679

# %%
# A list of the distance along the river between the locations is determined based on the riverlocations and X/Y-coordinates.    
dKM=[KM[n]-KM[n-1] for n in range(1,len(KM))] #distance between the locations
dX=[Xco[n]-Xco[n-1] for n in range(1,len(Xco))]
dY=[Yco[n]-Yco[n-1] for n in range(1,len(Yco))]

#print(dKM)

# %% [markdown]
# ## Define the hydraulic boundary conditions: incoming river discharge upstream of the river and the downstream water level based on a Q-h relation.

# %%
# This part describes the hydraulic boundary conditions: incoming river discharge upstream of the river and the downstream water level based on a Q-h relation.
# The upstream boundary condition is the incoming riverdischarge at Lobith. At bifurcation Pannerdensche kop a discharge distribution is applied 
# for the discharges into the Waal and the Pannerdensch channel. At the second bifurcation Ysselkop also a discharge distribution to the Nederrijn
# and the Yssel is implemented based on the information provided RWS Oost-Nederland. Information from year 2000 based on measurements 
# of the year 1998 & 1999 for closed barriers in the Nederrijn.

import csv
with open ('DD_Rhinebranches.csv') as f:   #Reading csv file with bathymetry data of the river Waal
    reader = csv.reader(f, delimiter=';')

# Define lists of river discharges
    qlobith=[]
    qwaal=[]
    qpkan=[]
    qneder=[]
    qyssel=[]
    qtotal=[]
        
    for row in reader:    
          
        qlobith.append(row[0]) # incoming discharge Lobith
        qwaal.append(row[1]) # discharge Waal
        qpkan.append(row[2]) # discharge Pannerdensch kanaal
        qneder.append(row[3]) #discharge Nederrijn
        qyssel.append(row[4]) #discharge Yssel

# Change items of list from strings to floating numbers or integer 
Qlob = [int(i) for i in qlobith] 
Qwaal = [int(i) for i in qwaal] 
Qpkan = [int(i) for i in qpkan] 
Qneder = [int(i) for i in qneder] 
Qyssel = [int(i) for i in qyssel]  

#print(Qyssel)

# %%
# In this cell the discharge distribution is defined based on the given river discharge of the Bovenrijn.
waal, = plt.plot(Qlob, Qwaal, label='Waal') 
pkan, = plt.plot(Qlob, Qpkan, label='Pann kanaal')               
neder, = plt.plot(Qlob, Qneder, label='Nederrijn') 
yssel, = plt.plot(Qlob, Qyssel, label='Yssel')
plt.title('Discharge distribution')
plt.legend(handles=[waal, pkan, neder, yssel])

plt.ylabel('Qriverstretch [m3/s]')
plt.xlabel('Q bovenrijn [m3/s]')

# River discharge division in case of closed barriers in the range of QLobith=823-1430 m3/s
qbovenrijn=1013

if qbovenrijn==700:
    qpkan=117
    qwaal=583
    qnederrijn=11
    qyssel=106
    bovenrijn_ben=633.2
    pankan_ben=612.7
    waal_ben=69
    neder_ben=600
    yssel_ben=-35
elif qbovenrijn==823:
    qpkan=150
    qwaal=673
    qnederrijn=30
    qyssel=120
    bovenrijn_ben=721.8
    pankan_ben=697.8
    waal_ben=69
    neder_ben=271.6
    yssel_ben=-32.5        
elif qbovenrijn==1013:
    qpkan=200
    qwaal=813
    qnederrijn=30
    qyssel=170
    pankan_ben=697.8
    waal_ben=69
    neder_ben=271.6
    yssel_ben=-32.5
else:
    print('No values.')
    
print('Qbovenrijn',qbovenrijn)
print('QPannerdensch Kanaal',qpkan)
print('QWaal',qwaal)
print('QNederrijn',qnederrijn)
print('QYssel',qyssel)
# Out:
# Qbovenrijn 1013
# QPannerdensch Kanaal 200
# QWaal 813
# QNederrijn 30
# QYssel 170

# %%
#Flip arrays for calculation starting at the downstream location of the riverstretch
Xco_flip=Xco[::-1]
Yco_flip=Yco[::-1]
KM_flip=KM[::-1]
dKM_flip=dKM[::-1]
Waterlevel_flip=Waterlevel[::-1]
Waterlevel700_flip=Waterlevels700[::-1]
Width_summerbed_flip=Width_summerbed[::-1]
Level_summerbed_flip=Level_summerbed[::-1]
Level_winterbed_flip=Level_winterbed[::-1] 
Chezy_flip=Chezy[::-1]

# Define the different riverstretches of the system
# Bovenrijn = cell 671:681 
xbovenrijn = KM_flip[671:681]
dKMbovenrijn = dKM_flip[671:681]
wlbovenrijn = Waterlevel700_flip[671:681]
wlbovenrijn700 = Waterlevel_flip[671:681]
WSbovenrijn = Width_summerbed_flip [671:681]
LSbovenrijn = Level_summerbed_flip[671:681]
LWbovenrijn = Level_winterbed_flip[671:861]

# Waal1 = cell 484:672
xwaal = KM_flip[569:670]
dKMwaal = dKM_flip[569:670]
wlwaal = Waterlevel_flip[569:670]
wlwaal700 = Waterlevel700_flip[569:670]
WSwaal = Width_summerbed_flip[569:670]
LSwaal = Level_summerbed_flip[569:670]
LWwaal = Level_winterbed_flip[569:670]
Chezywaal = Chezy_flip[569:670]

# Pannerdensch kanaal = cell 460:484
xpankan = KM_flip[460:484]
dKMpankan = dKM_flip[460:484]
wlpankan = Waterlevel_flip[460:484]
wlpankan700 = Waterlevel700_flip[460:484]
WSpankan = Width_summerbed_flip[460:484]
LSpankan = Level_summerbed_flip[460:484]
LWpankan = Level_winterbed_flip[460:484]

# Nederrijn = cell 360:460
xneder = KM_flip[434:459] #deel tot aan eerste sluis bovenstrooms van de Nederrijn is meegenomen in model
dKMneder = dKM_flip[434:459]
wlneder = Waterlevel_flip[434:459]
wlneder700 = Waterlevel700_flip[434:459]
WSneder = Width_summerbed_flip[434:459]
LSneder = Level_summerbed_flip[434:459]
LWneder = Level_winterbed_flip[434:459]

# Lek = cell 239:360 
xlek = KM_flip[239:360]
dKMlek = dKM_flip[239:360]
wllek = Waterlevel_flip[239:360]
wllek700 = Waterlevel700_flip[239:360]
WSlek = Width_summerbed_flip[239:360]
LSlek = Level_summerbed_flip[239:360]
LWlek = Level_winterbed_flip[239:360]

# Yssel = cell 10:239
xyssel = KM_flip[0:323]
dKMyssel = dKM_flip[0:323]
wlyssel = Waterlevel_flip[0:323]
wlyssel700 = Waterlevel700_flip[0:323]
WSyssel = Width_summerbed_flip[0:323]
LSyssel = Level_summerbed_flip[0:323]
LWyssel = Level_winterbed_flip[0:323]
Chezyyssel = Chezy_flip[0:323]

# %%
print(len(dKMyssel))
# Out:
# 323

# %% [markdown]
# ## Manning formula calculations to determine normal and critical flow depth.

# %%
#Channel slope
#According to De Vries (1993), Sieben (2009), Sloff et al.(2014) and Blom (2016), the channel slope of the Waal river is 1.0*10^-4
#and 1.2*10^-4.

S0=0.00012 #bed slope of the rivert
k=1 #roughnesse dependend on discharge
#Roughness of main channel
n=0.0295 
n2=0.08
n3=0.065
C0=1

#Riverstretch Bovenrijn

#normal flow
def Manning (y, qbovenrijn, b, S, n, k, m):
    A=(b+m*y)*y # conveyance surface area [m2] =>(width*depth)
    R=A/(b+2*y*(1+m**2)**(1/2)) #hydraulic radius [-]
    return qbovenrijn-(C0/n)*A*R**(2/3)*S**(1/2)
m=0

#normal flow depth in steady flowis also upstream water dept of river stretch 
y0_br = zeros(len(WSbovenrijn))
y0_br = [fsolve(Manning,1, args=(qbovenrijn, WSbovenrijn[i], S0, n, C0, m)) for i in range (0, len(WSbovenrijn))]  

#bovenstroomse waterstand van een traject dx tov NAP [m]=h_bov_e
waterlevels_normalbovenrijn =zeros(len(y0_br))
waterlevels_normalbovenrijn = [y0_br[i]*100+LSbovenrijn[i] for i in range(0, len(y0_br))] 

#Riverstretch Pannerdensch Kanaal

#normal flow
def Manning (y, qpkan, b, S, n2, k, m):
    A=(b+m*y)*y # conveyance surface area [m2] =>(width*depth)
    R=A/(b+2*y*(1+m**2)**(1/2)) #hydraulic radius [-]
    return qpkan-(C0/n)*A*R**(2/3)*S**(1/2)
m=0

#normal flow depth in steady flowis also upstream water dept of river stretch 
y0_pankan = zeros(len(WSpankan))
y0_pankan = [fsolve(Manning,1, args=(qpkan, WSpankan[i], S0, n2, C0, m)) for i in range (0, len(WSpankan))]  

#bovenstroomse waterstand van een traject dx tov NAP [m]=h_bov_e
waterlevels_normalpankan=zeros(len(y0_pankan))
waterlevels_normalpankan = [y0_pankan[i]*100+LSpankan[i] for i in range(0, len(y0_pankan))] 


#Riverstretch Nederrijn

#normal flow
def Manning (y, qnederrijn, b, S, n2, k, m):
    A=(b+m*y)*y # conveyance surface area [m2] =>(width*depth)
    R=A/(b+2*y*(1+m**2)**(1/2)) #hydraulic radius [-]
    return qnederrijn-(C0/n)*A*R**(2/3)*S**(1/2)
m=0

#normal flow depth in steady flowis also upstream water dept of river stretch 
y0_neder = zeros(len(WSneder))
y0_neder = [fsolve(Manning,1, args=(qnederrijn, WSneder[i], S0, n2, C0, m)) for i in range (0, len(WSneder))]  

#bovenstroomse waterstand van een traject dx tov NAP [m]=h_bov_e
waterlevels_normalneder = zeros(len(y0_neder))
waterlevels_normalneder = [y0_neder[i]*100+LSneder[i] for i in range(0, len(y0_neder))] 

#Riverstretch Waal & Yssel

#normal flow
def Manning (y, qwaal, b, S, n, k, m):
    A=(b+m*y)*y # conveyance surface area [m2] =>(width*depth)
    R=A/(b+2*y*(1+m**2)**(1/2)) #hydraulic radius [-]
    return qwaal-(C0/n)*A*R**(2/3)*S**(1/2)
m=0

#normal flow
def Manning (y, qyssel, b, S, n, k, m):
    A=(b+m*y)*y # conveyance surface area [m2] =>(width*depth)
    R=A/(b+2*y*(1+m**2)**(1/2)) #hydraulic radius [-]
    return qyssel-(C0/n)*A*R**(2/3)*S**(1/2)
m=0

#normal flow depth in steady flow is also upstream water dept of river stretch  
y0_waal = zeros(len(WSwaal))
#y0_yssel = zeros(len(WSyssel))

y0_waal = [fsolve(Manning,1, args=(qwaal, WSwaal[i], S0, n3, C0, m)) for i in range (0, len(WSwaal))] 
#y0_yssel1 = [fsolve(Manning,1, args=(qyssel, WSyssel[i], S0, n3, C0, m)) for i in range (139, len(WSyssel))] 

#bovenstroomse waterstand van een traject dx tov NAP [m]=h_bov_e
waterlevels_normalwaal =zeros(len(y0_waal))
#waterlevels_normalyssel1 =zeros(len(y0_yssel))

waterlevels_normalwaal = [y0_waal[i]*100+LSwaal[i] for i in range(0, len(y0_waal))] 
#waterlevels_normalyssel1 = [y0_yssel[i]*100+LSyssel[i] for i in range(139, len(y0_yssel))]

# %%
#Channel slope
#According to De Vries (1993), Sieben (2009), Sloff et al.(2014) and Blom (2016), the channel slope of the Waal river is 1.0*10^-4
#and 1.2*10^-4.

S0=0.00012 #bed slope of the rivert
k=1 #roughnesse dependend on discharge
#Roughness of main channel
n1=0.0295 
n2=0.08
n3=0.065
C0=1

#Riverstretch Yssel

#normal flow
def Manning (y, qyssel, b, S, n, k, m):
    A=(b+m*y)*y # conveyance surface area [m2] =>(width*depth)
    R=A/(b+2*y*(1+m**2)**(1/2)) #hydraulic radius [-]
    return qyssel-(C0/n)*A*R**(2/3)*S**(1/2)
m=0

#normal flow depth in steady flow is also upstream water dept of river stretch  
y0_yssel1 = zeros(139)
y0_yssel2 = zeros(90)
y0_yssel3 = zeros(94)
y0_yssel = zeros(323)

y0_yssel1 = [fsolve(Manning,1, args=(qyssel, WSyssel[i], S0, n1, C0, m)) for i in range (139)]
y0_yssel2 = [fsolve(Manning,1, args=(qyssel, WSyssel[i], S0, n2, C0, m)) for i in range (90)] 
y0_yssel3 = [fsolve(Manning,1, args=(qyssel, WSyssel[i], S0, n3, C0, m)) for i in range (94)] 
y0_yssel = [fsolve(Manning,1, args=(qyssel, WSyssel[i], S0, n3, C0, m)) for i in range (323)] 

#bovenstroomse waterstand van een traject dx tov NAP [m]=h_bov_e
waterlevels_normalyssel1 =zeros(139)
waterlevels_normalyssel2 =zeros(90)
waterlevels_normalyssel3 =zeros(94)
waterlevels_normalyssel =zeros(323)

waterlevels_normalyssel1 = [y0_yssel1[i]*100+LSyssel[i] for i in range(0,139)]
waterlevels_normalyssel2 [y0_yssel2[i]*100+LSyssel[i] for i in range(139,229)] 
waterlevels_normalyssel3= [y0_yssel3[i]*100+LSyssel[i] for i in range(229,323)] 
waterlevels_normalyssel = [waterlevels_normalyssel1,waterlevels_normalyssel2,waterlevels_normalyssel3]
# Out:
#   File "<ipython-input-44-ccb9e9db965b>", line 40
#     waterlevels_normalyssel2 [y0_yssel2[i]*100+LSyssel[i] for i in range(139,229)]
#                                                             ^
# SyntaxError: invalid syntax

# %%
print(y0_yssel1)
# Out:
# [array([2.59050558]), array([2.52517604]), array([2.42087496]), array([2.26642056]), array([2.17717585]), array([2.12600377]), array([2.11615373]), array([2.12600377]), array([2.14608019]), array([2.01535002]), array([1.88948315]), array([1.83402937]), array([1.75850732]), array([1.74090075]), array([1.75850732]), array([1.79520227]), array([1.78274333]), array([1.78274333]), array([1.78894366]), array([1.75258548]), array([1.8143368]), array([1.80789791]), array([1.84748108]), array([1.8407222]), array([1.91146845]), array([1.98178771]), array([1.8407222]), array([1.98178771]), array([1.92651296]), array([1.92651296]), array([1.88948315]), array([1.92651296]), array([1.8967358]), array([1.94968857]), array([1.98178771]), array([2.00681632]), array([2.14608019]), array([2.00681632]), array([1.99837921]), array([1.99837921]), array([1.99837921]), array([2.01535002]), array([2.04154912]), array([2.01535002]), array([2.04154912]), array([2.03271452]), array([2.05048789]), array([2.05953287]), array([2.06868614]), array([2.05953287]), array([2.05953287]), array([2.12600377]), array([2.13597839]), array([2.15631185]), array([2.12600377]), array([2.13597839]), array([2.09681734]), array([2.13597839]), array([2.12600377]), array([2.16667612]), array([2.19859346]), array([2.19859346]), array([2.23181186]), array([2.22058916]), array([2.23181186]), array([2.27828241]), array([2.30251755]), array([2.32746189]), array([2.32746189]), array([2.32746189]), array([2.32746189]), array([2.32746189]), array([2.35315009]), array([2.36628463]), array([2.35315009]), array([2.36628463]), array([2.393159]), array([2.37961925]), array([2.40690909]), array([2.36628463]), array([2.42087496]), array([2.393159]), array([2.37961925]), array([2.42087496]), array([2.42087496]), array([2.36628463]), array([2.35315009]), array([2.37961925]), array([2.37961925]), array([2.40690909]), array([2.42087496]), array([2.40690909]), array([2.46412431]), array([2.4350622]), array([2.40690909]), array([2.393159]), array([2.37961925]), array([2.40690909]), array([2.46412431]), array([2.4350622]), array([2.4350622]), array([2.40690909]), array([2.4350622]), array([2.47901146]), array([2.4941446]), array([2.50953046]), array([2.54108863]), array([2.46412431]), array([2.52517604]), array([2.50953046]), array([2.57374538]), array([2.54108863]), array([2.52517604]), array([2.54108863]), array([2.47901146]), array([2.46412431]), array([2.46412431]), array([2.50953046]), array([2.52517604]), array([2.52517604]), array([2.55727579]), array([2.52517604]), array([2.60756492]), array([2.60756492]), array([2.59050558]), array([2.59050558]), array([2.66062831]), array([2.55727579]), array([2.59050558]), array([2.55727579]), array([2.57374538]), array([2.62493226]), array([2.64261685]), array([2.54108863]), array([2.66062831]), array([2.54108863]), array([2.54108863]), array([2.50953046]), array([2.54108863])]

# %% [markdown]
# ## Bresse equation
#
# Based on the Bresse equation the backwatercurve based on the downstream water level can be determined.

# %%
# Riverstretch Bovenrijn & Pannerdensch Kanaal & Nederrijn
#chezy-coefficient
Cboven=48
Cpankan=41
Cneder=43

#discharge per unit width for each river stretch
qbr = [qbovenrijn/WSbovenrijn[n] for n in range (0, len(dKMbovenrijn))] 
qpk = [qpkan/WSpankan[n] for n in range (0, len(dKMpankan))]
qn = [qnederrijn/WSneder[n] for n in range (0, len(dKMneder))]

#equilibrium water depthfor each river stretch
h_eq_br = [(qbr[n]**2/((Cboven**2)*S0))**(1/3)for n in range (0, len(dKMbovenrijn))] 
h_eq_pankan = [(qpk[n]**2/((Cpankan**2)*S0))**(1/3)for n in range (0, len(dKMpankan))] 
h_eq_neder = [(qn[n]**2/((Cneder**2)*S0))**(1/3)for n in range (0, len(dKMneder))] 

#half length for each river stretch
#L_05 = [(0.24*cor_h_eq[n]/S0)*(y0[n]/cor_h_eq[n])**(4/3)for n in range (0, len(dKMbovenrijn))] 
L_05_normal_br = [(0.24*y0_br[n]/S0)*(y0_br[n-1]/y0_br[n])**(4/3)for n in range (0, len(dKMbovenrijn))]
L_05_normal_pankan = [(0.24*y0_pankan[n]/S0)*(y0_pankan[n-1]/y0_pankan[n])**(4/3)for n in range (0, len(dKMpankan))]
L_05_normal_neder = [(0.24*y0_neder[n]/S0)*(y0_neder[n-1]/y0_neder[n])**(4/3)for n in range (0, len(dKMneder))]

#bodemligging
dd0_bovenrijn = [waterlevels_normalbovenrijn[i+1]-waterlevels_normalbovenrijn[i]+dKMbovenrijn[i]*S0 for i in range(0, len(dKMbovenrijn))]
dd0_pankan = [waterlevels_normalpankan[i+1]-waterlevels_normalpankan[i]+dKMpankan[i]*S0 for i in range(0, 23)]
#dd0_neder = [waterlevels_normalneder[i+1]-waterlevels_normalneder[i]+dKMneder[i]*S0 for i in range(0, len(dKMneder))]

# %%
# Riverstrech Bovenrijn & Pannerdensch Kanaal & Nederrijn

hflip_bovenrijn = zeros(len(dKMbovenrijn))

for i in range (0,7):
    hflip_bovenrijn[0]=721.8
         
    #water level at location x+1    
    hflip_bovenrijn[i+1] = waterlevels_normalbovenrijn[i] + (hflip_bovenrijn[i]-waterlevels_normalbovenrijn[i]+S0*dKMbovenrijn[i])*(1/2)**(dKMbovenrijn[i]/L_05_normal_br[i])
    
    waterlevels_bovenrijn=hflip_bovenrijn[::-1]
    
    diff = zeros(len(waterlevels_bovenrijn))
    diff = [waterlevels_bovenrijn[i]-wlbovenrijn[i] for i in range(0,7)]
    
    
hflip_pankan = zeros(len(dKMpankan))

for i in range (0,23):
    hflip_pankan[0]=679.8
         
    #water level at location x+1    
    hflip_pankan[i+1] = waterlevels_normalpankan[i] + (hflip_pankan[i]-waterlevels_normalpankan[i]+S0*dKMpankan[i])*(1/2)**(dKMpankan[i]/L_05_normal_pankan[i])
    
    waterlevels_pankan=hflip_pankan#[::-1]
    
    diff = zeros(len(waterlevels_pankan))
    diff = [waterlevels_pankan[i]-wlpankan[i] for i in range(0,23)]
    
hflip_nederrijn = zeros(len(dKMneder))

for i in range (0,24):
    hflip_nederrijn[0]=696.6
         
    #water level at location x+1    
    hflip_nederrijn[i+1] = waterlevels_normalneder[i] + (hflip_nederrijn[i]-waterlevels_normalneder[i]+S0*dKMneder[i])*(1/2)**(dKMneder[i]/L_05_normal_neder[i])
    
    waterlevels_nederrijn=hflip_nederrijn#[::-1]
    
    diff = zeros(len(waterlevels_nederrijn))
    diff = [waterlevels_nederrijn[i]-wlneder[i] for i in range(0,24)]

# %%
print(len(waterlevels_normalbovenrijn))
# Out:
# 9

# %%
# Riverstretch Waal and Yssel
#chezy-coefficient
Cwaal=44
Cyssel=50

#discharge per unit width for each river stretch
qw = [qwaal/WSwaal[n] for n in range (0, len(dKMwaal))] 
qy = [qyssel/WSyssel[n] for n in range (139, len(dKMyssel))] 

#equilibrium water depthfor each river stretch
h_eq_waal = [(qw[n]**2/((Chezywaal[n]**2)*S0))**(1/3)for n in range (0, len(dKMwaal))]
#h_eq_yssel = [(qy[n]**2/((Chezyyssel[n]**2)*S0))**(1/3)for n in range (139, len(dKMyssel))] 

#L_05 = [(0.24*cor_h_eq[n]/S0)*(y0[n]/cor_h_eq[n])**(4/3)for n in range (0, len(dKMwaal))] 

#half length for each river stretch
L_05 = [(0.24*h_eq_waal[n]/S0)*(y0_waal[n]/h_eq_waal[n])**(4/3)for n in range (0, len(dKMwaal))] 
L_05_normal_waal = [(0.24*y0_waal[n]/S0)*(y0_waal[n-1]/y0_waal[n])**(4/3)for n in range (0, len(dKMwaal))]
L_05_normal_yssel = [(0.24*y0_yssel[n]/S0)*(y0_yssel[n-1]/y0_yssel[n])**(4/3)for n in range (139, len(dKMyssel))]

#bodemligging
#dd0_waal = [waterlevels_normalwaal[i+1]-waterlevels_normalwaal[i]+dKMwaal[i]*S0 for i in range(0,185)] 
#dd0_yssel = [waterlevels_normalyssel[i+1]-waterlevels_normalyssel[i]+dKMyssel[i]*S0 for i in range(139,len(dKMyssel))]

# %%
# Riverstretch Yssel
#chezy-coefficient

Cyssel=50

#discharge per unit width for each river stretch
qw = [qwaal/WSwaal[n] for n in range (0, len(dKMwaal))] 
qy1 = [qyssel/WSyssel[n] for n in range (139)]
qy2 = [qyssel/WSyssel[n] for n in range (90)] 
qy3 = [qyssel/WSyssel[n] for n in range (94)] 
qy = [qyssel/WSyssel[n] for n in range (323)] 
#equilibrium water depthfor each river stretch

h_eq_yssel1 = [(qy1[n]**2/((Chezyyssel[n]**2)*S0))**(1/3)for n in range (139)]
h_eq_yssel2 = [(qy2[n]**2/((Chezyyssel[n]**2)*S0))**(1/3)for n in range (90)] 
h_eq_yssel3 = [(qy3[n]**2/((Chezyyssel[n]**2)*S0))**(1/3)for n in range (94)]
h_eq_yssel = [(qy[n]**2/((Chezyyssel[n]**2)*S0))**(1/3)for n in range (323)] 


#L_05 = [(0.24*cor_h_eq[n]/S0)*(y0[n]/cor_h_eq[n])**(4/3)for n in range (0, len(dKMwaal))] 

#half length for each river stretch
L_05_normal_yssel = [(0.24*y0_yssel[n]/S0)*(y0_yssel[n-1]/y0_yssel[n])**(4/3)for n in range (323)]

#bodemligging
#dd0_yssel = [waterlevels_normalyssel[i+1]-waterlevels_normalyssel[i]+dKMyssel[i]*S0 for i in range(323)]

# %%
print(L_05[0:5],L_05_normal_waal[0:5])
# Out:
# [array([13988.93509072]), array([13886.74633824]), array([13720.95687062]), array([14023.46592519]), array([14023.46592519])] [array([11693.97317301]), array([12035.74736078]), array([11965.10755154]), array([11684.17622883]), array([12036.0045161])]

# %%
# Riverstretch Waal 

hflip_waal = zeros(len(dKMwaal))

#d0_waal = zeros(len(LSwaal))

for i in range (0,185):
    hflip_waal[0]=69
    
    #water level at location x+1  
    hflip_waal[i+1] = waterlevels_normalwaal[i] + (hflip_waal[i]-waterlevels_normalwaal[i]+S0*dKMwaal[i])*(1/2)**(dKMwaal[i]/L_05_normal_waal[i])
    
    waterlevels_waal=hflip_waal#[::-1]
    
    diff_waal = zeros(len(waterlevels_waal))
    diff_waal = [waterlevels_waal[i]-wlwaal[i] for i in range(0,185)]


    #hflip[i+1] = dflip[i] + cor_bl_sum[i]
    #h_wl = hflip[::-1]
    #d0[i+1]=dx_flip[i]*S#d0[i]+

    #dflip[i+1] = y0[i] + (dflip[i]-y0[i])*(1/2)**(dx_flip[i]/L_05_normal[i])#depth at location x+1
    #dd0[i] = [waterlevels_normal[i]-waterlevels[i-1]+dx_flip[i]*S 
    
    #hflip[i+1] = waterlevels_normal[i+1] + (dd0[i]*2)**(dx_flip[i]/L_05_normal[i])#water level at location x+1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-944607e785c8> in <module>()
#      14
#      15     diff_waal = zeros(len(waterlevels_waal))
# ---> 16     diff_waal = [waterlevels_waal[i]-wlwaal[i] for i in range(0,185)]
#      17
#      18
#
# <ipython-input-26-944607e785c8> in <listcomp>(.0)
#      14
#      15     diff_waal = zeros(len(waterlevels_waal))
# ---> 16     diff_waal = [waterlevels_waal[i]-wlwaal[i] for i in range(0,185)]
#      17
#      18
#
# IndexError: index 101 is out of bounds for axis 0 with size 101

# %%
#print(average(diff_waal))

# %%
# Riverstretch IJssel
hflip_yssel = zeros(90)
for i in range (90):
    hflip_yssel[0]=-35.5
    hflip_yssel[i+1] = waterlevels_normalyssel[i] + (hflip_yssel[i]-waterlevels_normalyssel[i]+S0*dKMyssel[i])*(1/2)**(dKMyssel[i]/L_05_normal_yssel[i])#water level at location x+1
    
    waterlevels_yssel=hflip_yssel#[::-1]
    
    diff_yssel = zeros(90)
    diff_yssel = [(waterlevels_yssel[i]-wlyssel[i])/100 for i in range(90)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-c1a4ed89f28a> in <module>()
#       3 for i in range (90):
#       4     hflip_yssel[0]=-35.5
# ----> 5     hflip_yssel[i+1] = waterlevels_normalyssel3[i] + (hflip_yssel[i]-waterlevels_normalyssel3[i]+S0*dKMyssel[i])*(1/2)**(dKMyssel[i]/L_05_normal_yssel[i])#water level at location x+1
#       6
#       7     waterlevels_yssel=hflip_yssel#[::-1]
#
# IndexError: index 90 is out of bounds for axis 0 with size 90

# %%
print(min(waterlevels_yssel))
# Out:
# -313864.2631242356

# %% [markdown]
# ### Module to determine the width-average waterdepth

# %%
depth_waal = [(waterlevels_waal[i]-LSwaal[i])/280 for i in range(0,185)]
depth_yssel = [(waterlevels_yssel[i]-LSyssel[i])/280 for i in range(139,228)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-31c528f15b51> in <module>()
# ----> 1 depth_waal = [(waterlevels_waal[i]-LSwaal[i])/280 for i in range(0,185)]
#       2 depth_yssel = [(waterlevels_yssel[i]-LSyssel[i])/280 for i in range(139,228)]
#
# <ipython-input-30-31c528f15b51> in <listcomp>(.0)
# ----> 1 depth_waal = [(waterlevels_waal[i]-LSwaal[i])/280 for i in range(0,185)]
#       2 depth_yssel = [(waterlevels_yssel[i]-LSyssel[i])/280 for i in range(139,228)]
#
# IndexError: index 101 is out of bounds for axis 0 with size 101

# %%
#This cell is added to plot figures based on the determined variables.
plt.figure(1)
waterdepth, =plt.plot(xwaal[0:93], depth_waal, label='Waterdepth')
#bottom, = plt.plot(xbovenrijn, LSbovenrijn, label='Bottom summerbed')
plt.title('Relatieve waterdiepte Waal')
plt.legend(handles=[waterdepth])
plt.ylabel('relatieve waterdiepte[cm]')
plt.xlabel('distance, x [m]')

plt.figure(2)
waterdepth, =plt.plot(xyssel[0:237], depth_yssel, label='Waterdepth')
#bottom, = plt.plot(xbovenrijn, LSbovenrijn, label='Bottom summerbed')
plt.title('Relatieve waterdiepte IJssel')
plt.legend(handles=[waterdepth])
plt.ylabel('relatieve waterdiepte[cm]')
plt.xlabel('distance, x [m]')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-2396b16ffb23> in <module>()
#       1 #This cell is added to plot figures based on the determined variables.
#       2 plt.figure(1)
# ----> 3 waterdepth, =plt.plot(xwaal[0:93], depth_waal, label='Waterdepth')
#       4 #bottom, = plt.plot(xbovenrijn, LSbovenrijn, label='Bottom summerbed')
#       5 plt.title('Relatieve waterdiepte Waal')
#
# NameError: name 'depth_waal' is not defined

# %% [markdown]
# ## Plotting figures of results

# %%
#This cell is added to plot figures based on the determined variables.
plt.figure(1)
model, =plt.plot(xbovenrijn, waterlevels_normalbovenrijn, label='Model')
bottom, = plt.plot(xbovenrijn, LSbovenrijn, label='Bottom summerbed')
plt.title('Waterlevels NAP [cm] for normal flow')
plt.legend(handles=[model, bottom])
plt.ylabel('level NAP [cm]')
plt.xlabel('distance, x [m]')

plt.figure(2)
model, =plt.plot(xbovenrijn, y0_br, label='Model')
plt.title('Waterdepths for normal flow')
plt.legend(handles=[model])
plt.ylabel('waterdepth[cm]')
plt.xlabel('distance, x [m]')
# Out:
# Text(0.5,0,'distance, x [m]')

# %%
#This cell is added to plot figures based on the determined variables.
plt.figure(1)
plt.plot(xwaal, waterlevels_normalwaal)
plt.ylabel('level NAP [cm]')
plt.xlabel('distance, x [m]')

plt.figure(2)
plt.plot(xyssel[139:228], waterlevels_normalyssel[139:228])
plt.ylabel('level NAP [cm]')
plt.xlabel('distance, x [m]')
# Out:
# Text(0.5,0,'distance, x [m]')

# %%
plt.figure(3)
model, = plt.plot(xneder, waterlevels_nederrijn, label='model') 
SOBEK, = plt.plot(xneder, wlneder, label='SOBEK-simulation')
bottom, = plt.plot(xneder, LSneder, label='Bottom summerbed')
plt.title('Levels NAP [cm] Nederrijn')
plt.legend(handles=[model, SOBEK, bottom])
plt.ylabel('level NAP [cm]')
plt.xlabel('distance [m]')
# Out:
# Text(0.5,0,'distance [m]')

# %%
# Plot of riverstretch Bovenrijn
plt.figure(1)
#nul, = plt.plot(xbovenrijn[0:8], dd0_bovenrijn[0:8], label='nul') 
model, = plt.plot(xbovenrijn[0:8], waterlevels_bovenrijn[0:8], label='model') 
SOBEK, = plt.plot(xbovenrijn[0:8], wlbovenrijn700[0:8], label='SOBEK-simulation')
bottom, = plt.plot(xbovenrijn[0:8], LSbovenrijn[0:8], label='Bottom summerbed')
plt.title('Levels NAP [cm] Bovenrijn')
plt.legend(handles=[model, SOBEK, bottom])
plt.ylabel('level NAP [cm]')
plt.xlabel('distance [m]')

# Plot of riverstretch Pannerdensch Kanaal
plt.figure(2)
#nul, = plt.plot(xpankan, dd0_pankan, label='nul') 
#normal, = plt.plot(xpankan, waterlevels_normalpankan, label='norm flow')
model, = plt.plot(xpankan, waterlevels_pankan, label='model') 
SOBEK, = plt.plot(xpankan, wlpankan700, label='SOBEK-simulation')
bottom, = plt.plot(xpankan, LSpankan, label='Bottom summerbed')
plt.title('Levels NAP [cm] Pannerdensch Kanaal')
plt.legend(handles=[model, SOBEK, bottom])
plt.ylabel('level NAP [cm]')
plt.xlabel('distance [m]')

# Plot of riverstretch Waal
plt.figure(3)
#normal, = plt.plot(xwaal[0:184], waterlevels_normalwaal[0:184], label='norm flow')
model, = plt.plot(xwaal[0:184], waterlevels_waal[0:184], label='model') 
SOBEK, = plt.plot(xwaal[0:184], wlwaal[0:184], label='SOBEK-simulation')
bottom, = plt.plot(xwaal[0:184], LSwaal[0:184], label='Bottom summerbed')
plt.title('Levels NAP [cm] Waal')
plt.legend(handles=[model, SOBEK, bottom])
plt.ylabel('level NAP [cm]')
plt.xlabel('distance [m]')


# Plot of riverstretch Yssel
plt.figure(4)
#normal, = plt.plot(xyssel, waterlevels_normalyssel, label='norm flow')
model, = plt.plot(xyssel[230:322], waterlevels_yssel[230:322], label='model') 
SOBEK, = plt.plot(xyssel[230:322], wlyssel[230:322], label='SOBEK-simulation')
bottom, = plt.plot(xyssel[230:322], LSyssel[230:322], label='Bottom summerbed')
plt.title('Levels NAP [cm] Yssel')
plt.legend(handles=[model, SOBEK, bottom])
plt.ylabel('level NAP [cm]')
plt.xlabel('distance, x [m]')
# Out:
# Text(0.5,0,'distance, x [m]')

# %% [markdown]
# ## Plotting the graph as applied in the SOBEK-schematisation in 2013.

# %%
import networkx as nx

# Definition of the nodes in the graph. The nodes in the graph are the locations of calculation points of the SOBEK-simulation.
G = nx.Graph()
G.add_node(location[0], pos=(X[0],Y[0]), name=(KM[0]))
#G.add_nodes_from(location[:], pos=(X[:],Y[:]), name=(KM[:]))

for i in enumerate(location()): #adds nodes with label 1 till n nodes to the network. 
    G.add_node(i, pos= (X[i],Y[i])
    #lat_lon_to_index[node] = i

#print(G.node[7])

# Definition of the edges between the nodes. The edges are defined by the different riverstreches given in the previous cell (definition of riverstretches). 
#def calculate_distance(Node1, Node2):
    # calculate distance between two points
   # distance = float(((Node2[0]-Node1[0])**2+(Node2[1]-Node1[1])**2)**0.5)
   # return float(distance)



#G.add_edge(location[0],location[1], dis= calculate_distance(nx.get_node_attributes(G, 'pos')[location[0]], nx.get_node_attributes(G, 'pos')[location[0]]))
 #for edge in G.edges(data=True): 
#G.add_edge(location[edge[0]], location[edge[1]], dis= calculate_distance(nx.get_node_attributes(G, 'pos')[location[edge[1]]], nx.get_node_attributes(G, 'pos')[location[edge[0]]]))   

    
#import matplotlib.pyplot as plt
#plt.figure(figsize=(18,18))
#nx.draw(G, nx.get_node_attributes(G, 'name'))


#nx.draw(w_G, nx.get_node_attributes(w_G, 'pos'), with_labels=True, node_size=0.5, font_size = 8)
# Out:
#   File "<ipython-input-70-39280ac6abc6>", line 32
#     #nx.draw(w_G, nx.get_node_attributes(w_G, 'pos'), with_labels=True, node_size=0.5, font_size = 8)
#                                                                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
#Write output to a CSV-file
import csv

with open('employee_file.csv', mode='w') as employee_file:
    employee_writer = csv.writer(employee_file, delimiter=';', quotechar='"', quoting=csv.QUOTE_MINIMAL)

    employee_writer.writerow([Xco_flip])
    #employee_writer.writerow(['Erica Meyers', 'IT', 'March'])

#with open(test, "w") as f:
    #writer = csv.writer(f)
    #for row in rows:
       # writer.writerow(row)

# %%
import xlsxwriter

# Create a workbook and add a worksheet.
workbook = xlsxwriter.Workbook('model.xlsx')
worksheet = workbook.add_worksheet()

# Some data we want to write to the worksheet.
expenses = xbovenrijn
    #['Rent', 1000],
    #['Gas',   100],
    #['Food',  300],
    #['Gym',    50],
#)

# Start from the first cell. Rows and columns are zero indexed.
row = 0
col = 0

# Iterate over the data and write it out row by row.
#for item, cost in (expenses):
    worksheet.write(row, col,     expenses)
    #worksheet.write(row, col + 1, cost)
    #row += 1

# Write a total using a formula.
#worksheet.write(row, 0, 'Total')
#worksheet.write(row, 1, '=SUM(B1:B4)')

workbook.close()
# Out:
#   File "<ipython-input-72-5fb3792f5b8b>", line 21
#     worksheet.write(row, col,     expenses)
#     ^
# IndentationError: unexpected indent
